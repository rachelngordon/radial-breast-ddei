# %%
import pandas as pd

df = pd.read_excel('breast_fastMRI_final.xlsx')
print(df[['Patient Coded Name', 'Data split (0=training, 1=testing)', 'Lesion status (0 = negative, 1= malignancy, 2= benign)', 'Laterality (1=right, 2=left)']].head())
# Out:
#    Patient Coded Name  Data split (0=training, 1=testing)  \
# 0  fastMRI_breast_001                                   0
# 1  fastMRI_breast_002                                   0
# 2  fastMRI_breast_003                                   0
# 3  fastMRI_breast_004                                   0
# 4  fastMRI_breast_005                                   0
#
#    Lesion status (0 = negative, 1= malignancy, 2= benign)  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#   Laterality (1=right, 2=left)
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN

# %% [markdown]
# # Split Train/Test and Calculate Counts

# %%
# List of incompatible patient names
incompatible_dirs = ['fastMRI_breast_272', 'fastMRI_breast_070', 'fastMRI_breast_237', 
                         'fastMRI_breast_114', 'fastMRI_breast_156', 'fastMRI_breast_279', 
                         'fastMRI_breast_289', 'fastMRI_breast_299', 'fastMRI_breast_159', 
                         'fastMRI_breast_048', 'fastMRI_breast_194', 'fastMRI_breast_240', 'fastMRI_breast_281']


# Step 1: Remove incompatible patient names
df_filtered = df[~df["Patient Coded Name"].isin(incompatible_dirs)]

# Step 2: Create separate lists for training and test sets
train_patients = df_filtered[df_filtered["Data split (0=training, 1=testing)"] == 0]["Patient Coded Name"].tolist()
test_patients = df_filtered[df_filtered["Data split (0=training, 1=testing)"] == 1]["Patient Coded Name"].tolist()

train_lesion_counts = df_filtered[df_filtered["Data split (0=training, 1=testing)"] == 0]["Lesion status (0 = negative, 1= malignancy, 2= benign)"].value_counts()
test_lesion_counts = df_filtered[df_filtered["Data split (0=training, 1=testing)"] == 1]["Lesion status (0 = negative, 1= malignancy, 2= benign)"].value_counts()

train_lesion_laterality = df_filtered[df_filtered["Data split (0=training, 1=testing)"] == 0][df_filtered["Lesion status (0 = negative, 1= malignancy, 2= benign)"] == 1]["Laterality (1=right, 2=left)"].value_counts()
test_lesion_laterality = df_filtered[df_filtered["Data split (0=training, 1=testing)"] == 1][df_filtered["Lesion status (0 = negative, 1= malignancy, 2= benign)"] == 1]["Laterality (1=right, 2=left)"].value_counts()

# Print results
print("Training Patients:", train_patients)
print("Test Patients:", test_patients)

print("Training Patients:", len(train_patients))
print("Test Patients:", len(test_patients))

print("Training Lesion Counts:", train_lesion_counts)
print("Test Lesion Counts:", test_lesion_counts)

print("Training Laterality Counts:", train_lesion_laterality)
print("Test Laterality Counts:", test_lesion_laterality)
# Out:
# Training Patients: ['fastMRI_breast_001', 'fastMRI_breast_002', 'fastMRI_breast_003', 'fastMRI_breast_004', 'fastMRI_breast_005', 'fastMRI_breast_007', 'fastMRI_breast_008', 'fastMRI_breast_009', 'fastMRI_breast_010', 'fastMRI_breast_012', 'fastMRI_breast_013', 'fastMRI_breast_014', 'fastMRI_breast_015', 'fastMRI_breast_016', 'fastMRI_breast_020', 'fastMRI_breast_022', 'fastMRI_breast_024', 'fastMRI_breast_027', 'fastMRI_breast_031', 'fastMRI_breast_032', 'fastMRI_breast_033', 'fastMRI_breast_036', 'fastMRI_breast_037', 'fastMRI_breast_038', 'fastMRI_breast_039', 'fastMRI_breast_040', 'fastMRI_breast_041', 'fastMRI_breast_042', 'fastMRI_breast_043', 'fastMRI_breast_044', 'fastMRI_breast_045', 'fastMRI_breast_046', 'fastMRI_breast_047', 'fastMRI_breast_049', 'fastMRI_breast_050',
# Test Patients: ['fastMRI_breast_006', 'fastMRI_breast_011', 'fastMRI_breast_017', 'fastMRI_breast_018', 'fastMRI_breast_019', 'fastMRI_breast_021', 'fastMRI_breast_023', 'fastMRI_breast_025', 'fastMRI_breast_026', 'fastMRI_breast_028', 'fastMRI_breast_029', 'fastMRI_breast_030', 'fastMRI_breast_034', 'fastMRI_breast_035', 'fastMRI_breast_058', 'fastMRI_breast_060', 'fastMRI_breast_065', 'fastMRI_breast_069', 'fastMRI_breast_084', 'fastMRI_breast_085', 'fastMRI_breast_087', 'fastMRI_breast_094', 'fastMRI_breast_100', 'fastMRI_breast_101', 'fastMRI_breast_127', 'fastMRI_breast_152', 'fastMRI_breast_162', 'fastMRI_breast_177', 'fastMRI_breast_181', 'fastMRI_breast_230', 'fastMRI_breast_232', 'fastMRI_breast_234', 'fastMRI_breast_236', 'fastMRI_breast_239', 'fastMRI_breast_241', 'fastMRI_breast_246', 'fastMRI_breast_248', 'fastMRI_breast_249', 'fastMRI_breast_252', 'fastMRI_breast_254', 'fastMRI_breast_258', 'fastMRI_breast_259', 'fastMRI_breast_269', 'fastMRI_breast_271', 'fastMRI_breast_283', 'fastMRI_breast_286', 'fastMRI_breast_287', 'fastMRI_breast_288', 'fastMRI_breast_290', 'fastMRI_breast_291', 'fastMRI_breast_293', 'fastMRI_breast_294', 'fastMRI_breast_295', 'fastMRI_breast_297', 'fastMRI_breast_298']
# Training Patients: 232
# Test Patients: 55
# Training Lesion Counts: Lesion status (0 = negative, 1= malignancy, 2= benign)
# 2    124
# 1     67
# 0     41
# Name: count, dtype: int64
# Test Lesion Counts: Lesion status (0 = negative, 1= malignancy, 2= benign)
# 2    30
# 1    15
# 0    10
# Name: count, dtype: int64
# Training Laterality Counts: Laterality (1=right, 2=left)
# 1    40
# 2    27
# Name: count, dtype: int64
# Test Laterality Counts: Laterality (1=right, 2=left)
# 2    10
# 1     5
# Name: count, dtype: int64
# /tmp/ipykernel_991512/980187914.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   train_lesion_laterality = df_filtered[df_filtered["Data split (0=training, 1=testing)"] == 0][df_filtered["Lesion status (0 = negative, 1= malignancy, 2= benign)"] == 1]["Laterality (1=right, 2=left)"].value_counts()
# /tmp/ipykernel_991512/980187914.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   test_lesion_laterality = df_filtered[df_filtered["Data split (0=training, 1=testing)"] == 1][df_filtered["Lesion status (0 = negative, 1= malignancy, 2= benign)"] == 1]["Laterality (1=right, 2=left)"].value_counts()

# %% [markdown]
# # Move Test Data to Separate Folder

# %%
import os
import shutil

# Define directories
parent_directory = "/ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps"  # Directory containing all patient folders
destination_directory = "/ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps"  # Where test patient folders will be moved


# Ensure the destination directory exists
os.makedirs(destination_directory, exist_ok=True)

# Move matching directories
for patient in test_patients:
    patient_dir = os.path.join(parent_directory, patient + '_1_cs_maps')
    
    # Check if directory exists before moving
    if os.path.isdir(patient_dir):
        shutil.move(patient_dir, os.path.join(destination_directory, patient + '_1_cs_maps'))
        print(f"Moved: {patient_dir} -> {destination_directory}")
    else:
        print(f"Directory not found: {patient_dir}")

print("All test patient directories have been moved.")
# Out:
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_006_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_011_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_017_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_018_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_019_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_021_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_023_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_025_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_026_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_028_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_029_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_030_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_034_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_035_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_058_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_060_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_065_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_069_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_084_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_085_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_087_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_094_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_100_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_101_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_127_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_152_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_162_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_177_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_181_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_230_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_232_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_234_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_236_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_239_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_241_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_246_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_248_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_249_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_252_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_254_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_258_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_259_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_269_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_271_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_283_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_286_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_287_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_288_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_290_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_291_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_293_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_294_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_295_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_297_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# Moved: /ess/scratch/scratch1/rachelgordon/pre_contrast_fs/cs_maps/fastMRI_breast_298_1_cs_maps -> /ess/scratch/scratch1/rachelgordon/test_data/pre_contrast_fs/cs_maps
# All test patient directories have been moved.

# %% [markdown]
# # Rename/Reorganize Data

# %%
# rename cs maps directories
import os

# Define the parent directory containing the subdirectories
parent_directory = "/ess/scratch/scratch1/rachelgordon/complex_fully_sampled/cs_maps"  # Change this to your directory

# Iterate through all items in the directory
for dir_name in os.listdir(parent_directory):
    old_path = os.path.join(parent_directory, dir_name)

    # Ensure it is a directory
    if os.path.isdir(old_path):
        # Check if it already ends with '_cs_maps'
        if not dir_name.endswith("_cs_maps"):
            new_name = dir_name + "_cs_maps"
            new_path = os.path.join(parent_directory, new_name)

            # Rename the directory
            os.rename(old_path, new_path)
            print(f"Renamed: {dir_name} -> {new_name}")

print("Renaming completed.")
# Out:
# Renamed: fastMRI_breast_096_1 -> fastMRI_breast_096_1_cs_maps
# Renamed: fastMRI_breast_050_1 -> fastMRI_breast_050_1_cs_maps
# Renamed: fastMRI_breast_141_1 -> fastMRI_breast_141_1_cs_maps
# Renamed: fastMRI_breast_251_1 -> fastMRI_breast_251_1_cs_maps
# Renamed: fastMRI_breast_111_1 -> fastMRI_breast_111_1_cs_maps
# Renamed: fastMRI_breast_014_1 -> fastMRI_breast_014_1_cs_maps
# Renamed: fastMRI_breast_032_1 -> fastMRI_breast_032_1_cs_maps
# Renamed: fastMRI_breast_004_1 -> fastMRI_breast_004_1_cs_maps
# Renamed: fastMRI_breast_270_1 -> fastMRI_breast_270_1_cs_maps
# Renamed: fastMRI_breast_161_1 -> fastMRI_breast_161_1_cs_maps
# Renamed: fastMRI_breast_040_1 -> fastMRI_breast_040_1_cs_maps
# Renamed: fastMRI_breast_173_1 -> fastMRI_breast_173_1_cs_maps
# Renamed: fastMRI_breast_288_1 -> fastMRI_breast_288_1_cs_maps
# Renamed: fastMRI_breast_091_1 -> fastMRI_breast_091_1_cs_maps
# Renamed: fastMRI_breast_179_1 -> fastMRI_breast_179_1_cs_maps
# Renamed: fastMRI_breast_285_1 -> fastMRI_breast_285_1_cs_maps
# Renamed: fastMRI_breast_102_1 -> fastMRI_breast_102_1_cs_maps
# Renamed: fastMRI_breast_223_1 -> fastMRI_breast_223_1_cs_maps
# Renamed: fastMRI_breast_057_1 -> fastMRI_breast_057_1_cs_maps
# Renamed: fastMRI_breast_242_1 -> fastMRI_breast_242_1_cs_maps
# Renamed: fastMRI_breast_108_1 -> fastMRI_breast_108_1_cs_maps
# Renamed: fastMRI_breast_128_1 -> fastMRI_breast_128_1_cs_maps
# Renamed: fastMRI_breast_139_1 -> fastMRI_breast_139_1_cs_maps
# Renamed: fastMRI_breast_053_1 -> fastMRI_breast_053_1_cs_maps
# Renamed: fastMRI_breast_073_1 -> fastMRI_breast_073_1_cs_maps
# Renaming completed.
