# %%
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np

# Load NIfTI file
nifti_file = '/ess/scratch/scratch1/rachelgordon/reconresnet/fully_sampled_gt/fastMRI_breast_001_2/slice_000_frame_000.nii' 
nifti_img = nib.load(nifti_file)

# Get the image data as a numpy array
data = nifti_img.get_fdata()

print(data.shape)
# Out:
# (320, 320)

# %%
# Plot the chosen slice
plt.imshow(data, cmap='gray')
plt.colorbar()
plt.title(f'Slice 0, Frame 0')
plt.show()
