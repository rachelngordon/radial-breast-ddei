# %%
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np

# %%
slice = 0

# load combined image
nifti_file = f"/ess/scratch/scratch1/rachelgordon/192_slices_1_timeframe/fastMRI_breast_001_2/slice_{slice:03d}_frame_000.nii"
img = nib.load(nifti_file)
combined_img_data = img.get_fdata()

combined_img_data_complex = combined_img_data[0] + 1j * combined_img_data[1]
print(combined_img_data_complex.shape)

# Plot
plt.imshow(np.abs(combined_img_data_complex), cmap='gray')
plt.axis('off')
plt.show()
# Out:
# (320, 320)

# %%
slice = 1

# load combined image
nifti_file = f"/ess/scratch/scratch1/rachelgordon/83_slices_1_timeframe/slice_{slice:03d}_frame_000.nii"
img = nib.load(nifti_file)
combined_img_data = img.get_fdata()

# combined_img_data_complex = combined_img_data[0] + 1j * combined_img_data[1]
print(combined_img_data.shape)

# Plot
plt.imshow(combined_img_data, cmap='gray')
plt.axis('off')
plt.show()
# Out:
# (320, 320)
